# %% [markdown]
# <a href="https://colab.research.google.com/github/tomtyiu/Fireball-series/blob/main/Math_and_FInance_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import getpass
import os

from google.colab import userdata


os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get('HF_TOKEN')

# %%
# !pip install --upgrade --quiet  langchain-huggingface text-generation transformers google-search-results numexpr langchainhub sentencepiece jinja2 bitsandbytes accelerate langchain_community
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00
#   Building wheel for google-search-results (setup.py) ... done

# %%
from langchain_community.llms import HuggingFaceEndpoint
from langchain_community.chat_models.huggingface import ChatHuggingFace

from transformers import BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
    bnb_4bit_use_double_quant=True,
)

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
    model_id="EpistemeAI/Fireball-Meta-Llama-3.1-8B-Instruct-Agent-0.003",
    task="text-generation",
    pipeline_kwargs=dict(
        max_new_tokens=2048,
        do_sample=False,
        repetition_penalty=1.03,
        return_full_text=False,
    ),
    model_kwargs={"quantization_config": quantization_config},
)

chat_model = ChatHuggingFace(llm=llm)
# Out:
# tokenizer_config.json:   0%|          | 0.00/55.3k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# pytorch_model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# pytorch_model-00001-of-00004.bin:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00004.bin:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# pytorch_model-00003-of-00004.bin:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# pytorch_model-00004-of-00004.bin:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# WARNING:langchain_huggingface.llms.huggingface_pipeline:Setting the `device` argument to None from -1 to avoid the error caused by attempting to move the model that was already loaded on the GPU using the Accelerate module to the same or another device.

# %%
# !pip install langchain_experimental
# Out:
# Requirement already satisfied: langchain_experimental in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain_experimental) (0.3.1)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from langchain_experimental) (0.3.6)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.1.129)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.1->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.2.2)

# %%
from langchain_core.tools import Tool
from langchain_experimental.utilities import PythonREPL

def get_python_repl(ai_msg):
    python_repl = PythonREPL()
    # You can create the tool to pass to an agent
    print(python_repl.run(ai_msg))


def chatbot(input_user):
  from langchain_core.messages import (
      HumanMessage,
      SystemMessage,
  )

  messages = [
      SystemMessage(content=
      """
      Environment: ipython. Tools: brave_search, wolfram_alpha. Cutting Knowledge Date: December 2023. Today Date: 24 August 2024\n
      You are a coding assistant with expert with everything\n
      Ensure any code you provide can be executed \n
      with all required imports and variables defined. List the imports.  Structure your answer with a description of the code solution. \n
      write only the code. do not print anything else.\n
      use ipython for search tool. \n
      debug code if error occurs. \n
      Here is the user question: {question}
      """
      ),
      HumanMessage(
          content=input_user
      ),
  ]

  ai_msg = chat_model.invoke(messages)
  print(ai_msg.content)
  get_python_repl(ai_msg.content)
  print ("double checking>>>")
  from langchain_core.messages import (
      HumanMessage,
      SystemMessage,
  )

  messages = [
      SystemMessage(content=
      """
      Environment: ipython. Tools: brave_search, wolfram_alpha. Cutting Knowledge Date: December 2023. Today Date: 24 Auguest 2024\n
      You are a debug assistant. find bugs and fix the bugs nad refactor\n
      Ensure any code you provide can be executed \n
      with all required imports and variables defined. List the imports.  Structure your answer with a description of the code solution. \n
      write only the code. do not print anything else.\n
      use ipython for search tool. \n
      debug code if error occurs. \n
      if no error, please provide no code \n
      if error, fix the code and provide the code\n
      """
      ),
      HumanMessage(
          content=ai_msg.content
      ),
  ]

  ai_msg_2 = chat_model.invoke(messages)
  print(ai_msg_2.content)
  get_python_repl(ai_msg_2.content)

print("=======================================================================")
print("Welcome to your own Agent Llama 3.1 8B Chatbot")
print("=======================================================================")

query = ""
while query != "bye":
  query = input("USER>>")
  chatbot(query)
  #print(f"\033[1m Chatbot>>:\033[0m {response}")
# Out:
# =======================================================================
# Welcome to your own Agent Llama 3.1 8B Chatbot
# =======================================================================
# USER>>What is (44232 + 13312 / (232 - 32)) * 5?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# result = (44232 + 13312 / (232 - 32)) * 5
# print(result)
# 221492.8
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# result = (44232 + 13312 / (232 - 32)) * 5
# print(result)
# 221492.8
#
# USER>>Write Python code to calculate the 14th Fibonacci number.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# def fibonacci(n):
#     if n <= 0:
#         return "Input should be a positive integer."
#     elif n == 1:
#         return 0
#     elif n == 2:
#         return 1
#     else:
#         fib_sequence = [0, 1]
#         while len(fib_sequence) < n:
#             fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])
#         return fib_sequence[-1]
#
# print(fibonacci(14))
# 233
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# def fibonacci(n):
#     if not isinstance(n, int) or n <= 0:
#         return "Input should be a positive integer."
#     elif n == 1:
#         return 0
#     elif n == 2:
#         return 1
#     else:
#         fib_sequence = [0, 1]
#         while len(fib_sequence) < n:
#             fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])
#         return fib_sequence[-1]
#
# print(fibonacci(14))
# 233
#
# USER>>wrong and debug: def fibonacci(n):     if not isinstance(n, int) or n <= 0:         return "Input should be a positive integer."     elif n == 1:         return 0     elif n == 2:         return 1     else:         fib_sequence = [0, 1]         while len(fib_sequence) < n:             fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])         return fib_sequence[-1]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# USER>>debug def fibonacci(n):     if not isinstance(n, int) or n <= 0:         return "Input should be a positive integer."     elif n == 1:         return 0     elif n == 2:         return 1     else:         fib_sequence = [0, 1]         while len(fib_sequence) < n:             fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])         return fib_sequence[-1]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# USER>>def fibonacci(n):     if not isinstance(n, int) or n <= 0:         return "Input should be a positive integer."     elif n == 1:         return 0     elif n == 2:         return 1     else:         fib_sequence = [0, 1]         while len(fib_sequence) < n:             fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])         return fib_sequence[-1]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# USER>>Create a plot showing the market caps of the top 7 publicly listed companies using data from Yahoo Finance
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Get the market caps of the top 7 publicly listed companies
# tickers = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB', 'TSLA', 'BABA']
# market_caps = []
# for ticker in tickers:
#     info = yf.Ticker(ticker).info
#     market_caps.append(info['marketCap'])
#
# # Create a DataFrame
# df = pd.DataFrame({'Company': tickers, 'Market Cap (USD)': market_caps})
#
# # Sort the DataFrame by market cap in descending order
# df = df.sort_values(by='Market Cap (USD)', ascending=False)
#
# # Plot the top 7 companies
# plt.figure(figsize=(10,6))
# plt.bar(df['Company'], df['Market Cap (USD)'])
# plt.xlabel('Company')
# plt.ylabel('Market Cap (USD)')
# plt.title('Market Caps of Top 7 Publicly Listed Companies')
# plt.xticks(rotation=90)
# plt.tight_layout()
# plt.show()
# KeyError('marketCap')
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Get the market caps of the top 7 publicly listed companies
# tickers = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB', 'TSLA', 'BABA']
# market_caps = []
# for ticker in tickers:
#     info = yf.Ticker(ticker).info
#     market_caps.append(info.get('marketCap'))  # Use get() method to avoid KeyError
#
# # Create a DataFrame
# df = pd.DataFrame({'Company': tickers, 'Market Cap (USD)': market_caps})
#
# # Sort the DataFrame by market cap in descending order
# df = df.sort_values(by='Market Cap (USD)', ascending=False)
#
# # Plot the top 7 companies
# plt.figure(figsize=(10,6))
# plt.bar(df['Company'], df['Market Cap (USD)'])
# plt.xlabel('Company')
# plt.ylabel('Market Cap (USD)')
# plt.title('Market Caps of Top 7 Publicly Listed Companies')
# plt.xticks(rotation=90)
# plt.tight_layout()
# plt.show()
# USER>>Given $30$ students such that each student has at most $5$ friends and for every $5$ students there is a pair of students that are not friends, determine the maximum $k$ such that for all such possible configurations, there exists $k$ students who are all not friends.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# def find_max_k():
#     n = 30
#     m = 5
#     k = 0
#     for i in range(1, n + 1):
#         for j in range(1, n + 1):
#             if i!= j:
#                 k += 1
#                 if k > n // 2:
#                     return k
#     return k
#
# result = find_max_k()
# print(result)
# 16
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# def find_max_k():
#     n = 30
#     m = 5
#     k = 0
#     for i in range(1, n + 1):
#         for j in range(i + 1, n + 1):  # Changed the range to start from i + 1 to avoid counting pairs twice
#             k += 1
#             if k > n // 2:
#                 return k
#     return k
#
# result = find_max_k()
# print(result)
# 16
#
# USER>>think carefully, Given $30$ students such that each student has at most $5$ friends and for every $5$ students there is a pair of students that are not friends, determine the maximum $k$ such that for all such possible configurations, there exists $k$ students who are all not friends.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# def find_max_k():
#     n = 30
#     m = 5
#     k = 0
#     for i in range(1, n + 1):
#         for j in range(1, n + 1):
#             if i!= j:
#                 k += 1
#                 if k > n // 2:
#                     return k
#     return k
#
# print(find_max_k())
# 16
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# def find_max_k():
#     n = 30
#     m = 5
#     k = 0
#     for i in range(1, n + 1):
#         for j in range(i + 1, n + 1):  # Changed the range to start from i + 1 to avoid counting pairs twice
#             k += 1
#             if k > n // 2:
#                 return k
#     return k
#
# print(find_max_k())
# 16
#
# USER>>Consider pairs $(f,g)$ of functions from the set of nonnegative integers to itself such that [list] [*]$f(0) \geq f(1) \geq f(2) \geq \dots \geq f(300) \geq 0$ [*]$f(0)+f(1)+f(2)+\dots+f(300) \leq 300$ [*]for any 20 nonnegative integers $n_1, n_2, \dots, n_{20}$, not necessarily distinct, we have $$g(n_1+n_2+\dots+n_{20}) \leq f(n_1)+f(n_2)+\dots+f(n_{20}).$$ [/list] Determine the maximum possible value of $g(0)+g(1)+\dots+g(6000)$ over all such pairs of functions.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import itertools
#
# def max_sum_g():
#     max_sum = 0
#     for f in itertools.product(range(301), repeat=301):
#         g = [0] * 6001
#         for i in range(301):
#             g[i] = f[i]
#         for i in range(301, 6001):
#             g[i] = min(f[i - 301] + f[i - 300], g[i - 1])
#         if all(g[i] >= g[i + 1] for i in range(6000)):
#             if sum(g) <= 300:
#                 max_sum = max(max_sum, sum(g))
#     return max_sum
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import itertools
#
# def max_sum_g():
#     max_sum = 0
#     for f in itertools.product(range(301), repeat=301):
#         g = [0] * 6001
#         for i in range(301):
#             g[i] = f[i]
#         for i in range(301, 6001):
#             g[i] = min(f[i - 301] + f[i - 300], g[i - 1])
#         if all(g[i] >= g[i + 1] for i in range(6000)):
#             if sum(g) <= 300:
#                 max_sum = max(max_sum, sum(g))
#     return max_sum
#
# USER>>debug import itertools  def max_sum_g():     max_sum = 0     for f in itertools.product(range(301), repeat=301):         g = [0] * 6001         for i in range(301):             g[i] = f[i]         for i in range(301, 6001):             g[i] = min(f[i - 301] + f[i - 300], g[i - 1])         if all(g[i] >= g[i + 1] for i in range(6000)):             if sum(g) <= 300:                 max_sum = max(max_sum, sum(g))     return max_sum
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import itertools
#
# def max_sum_g():
#     max_sum = 0
#     for f in itertools.product(range(301), repeat=301):
#         g = [0] * 6001
#         for i in range(301):
#             g[i] = f[i]
#         for i in range(301, 6001):
#             g[i] = min(f[i - 301] + f[i - 300], g[i - 1])
#         if all(g[i] >= g[i + 1] for i in range(6000)):
#             if sum(g) <= 300:
#                 max_sum = max(max_sum, sum(g))
#     return max_sum
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import itertools
#
# def max_sum_g():
#     max_sum = 0
#     for f in itertools.product(range(301), repeat=301):
#         g = [0] * 6001
#         for i in range(301):
#             g[i] = f[i]
#         for i in range(301, 6001):
#             g[i] = min(f[i - 301] + f[i - 300], g[i - 1])
#         if all(g[i] >= g[i + 1] for i in range(6000)):
#             if sum(g) <= 300:
#                 max_sum = max(max_sum, sum(g))
#     return max_sum
#
# USER>>Determine all positive integers $n$, $n\ge2$, such that the following statement is true: If $(a_1,a_2,...,a_n)$ is a sequence of positive integers with $a_1+a_2+\cdots+a_n=2n-1$, then there is block of (at least two) consecutive terms in the sequence with their (arithmetic) mean being an integer.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# def has_consecutive_integer_mean(a):
#     n = len(a)
#     for i in range(n - 1):
#         avg = (a[i] + a[i + 1]) / 2
#         if avg == int(avg):
#             return True
#     return False
#
# def has_block_of_consecutive_terms_with_integer_mean(a, n):
#     for i in range(len(a) - 1):
#         for j in range(i + 1, len(a)):
#             block = a[i:j + 1]
#             avg = sum(block) / len(block)
#             if avg == int(avg):
#                 return True
#     return False
#
# def find_n():
#     n_values = []
#     for n in range(2, 100):  # considering n up to 100
#         for a in itertools.combinations_with_replacement(range(1, 2 * n), n):
#             if sum(a) == 2 * n - 1 and has_block_of_consecutive_terms_with_integer_mean(a, n):
#                 n_values.append(n)
#                 break
#     return n_values
#
# import itertools
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
# import itertools
#
# def has_consecutive_integer_mean(a):
#     n = len(a)
#     for i in range(n - 1):
#         avg = (a[i] + a[i + 1]) / 2
#         if avg == int(avg):
#             return True
#     return False
#
# def has_block_of_consecutive_terms_with_integer_mean(a, n):
#     for i in range(len(a) - 1):
#         for j in range(i + 1, len(a)):
#             block = a[i:j + 1]
#             avg = sum(block) / len(block)
#             if avg == int(avg):
#                 return True
#     return False
#
# def find_n():
#     n_values = []
#     for n in range(2, 100):  # considering n up to 100
#         for a in itertools.combinations_with_replacement(range(1, 2 * n), n):
#             if sum(a) == 2 * n - 1 and has_block_of_consecutive_terms_with_integer_mean(a, n):
#                 n_values.append(n)
#                 break
#     return n_values
#
# USER>>import numpy as np import matplotlib.pyplot as plt x = np.random.randint(0, 100, 100) y = np.random.randint(0, 100, 100) plt.scatter(x, y) plt.savefig('scatter.png') print('Scatter plot saved to scatter.png')
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import numpy as np
# import matplotlib.pyplot as plt
#
# x = np.random.randint(0, 100, 100)
# y = np.random.randint(0, 100, 100)
#
# plt.scatter(x, y)
# plt.savefig('scatter.png')
# print('Scatter plot saved to scatter.png')
# Scatter plot saved to scatter.png
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate random x and y coordinates
# x = np.random.randint(0, 100, 100)
# y = np.random.randint(0, 100, 100)
#
# # Create a scatter plot
# plt.scatter(x, y)
#
# # Save the plot to a file
# plt.savefig('scatter.png')
#
# # Print a success message
# print('Scatter plot saved to scatter.png')
# Scatter plot saved to scatter.png
#
# USER>>import os  print(os.listdir(temp_dir.name))
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import os
# import tempfile
#
# temp_dir = tempfile.TemporaryDirectory()
# print(os.listdir(temp_dir.name))
# []
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import os
# import tempfile
#
# with tempfile.TemporaryDirectory() as temp_dir:
#     print(os.listdir(temp_dir))
# []
#
# USER>>'Use this fact to answer the question: Title of each class Trading Symbol(s) Name of each exchange on which registered Common Stock, Par Value $.01 Per Share MMM New York Stock Exchange MMM Chicago Stock Exchange, Inc. 1.500% Notes due 2026 MMM26 New York Stock Exchange 1.750% Notes due 2030 MMM30 New York Stock Exchange 1.500% Notes due 2031 MMM31 New York Stock Exchange  Which debt securities are registered to trade on a national securities exchange under 3M's name as of Q2 of 2023?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import pandas as pd
#
# # Define the data
# data = {
#     'Trading Symbol': ['MMM', 'MMM26', 'MMM30', 'MMM31'],
#     'Name of each exchange on which registered': ['New York Stock Exchange', 'New York Stock Exchange', 'New York Stock Exchange', 'New York Stock Exchange'],
#     'Security Type': ['Common Stock, Par Value $.01 Per Share', '1.500% Notes due 2026', '1.750% Notes due 2030', '1.500% Notes due 2031']
# }
#
# # Create a DataFrame
# df = pd.DataFrame(data)
#
# # Filter the DataFrame to get the debt securities
# debt_securities = df[df['Security Type'].str.contains('Notes')]
#
# # Print the result
# print(debt_securities)
#   Trading Symbol Name of each exchange on which registered  \
# 1          MMM26                   New York Stock Exchange
# 2          MMM30                   New York Stock Exchange
# 3          MMM31                   New York Stock Exchange
#
#            Security Type
# 1  1.500% Notes due 2026
# 2  1.750% Notes due 2030
# 3  1.500% Notes due 2031
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import pandas as pd
#
# # Define the data
# data = {
#     'Trading Symbol': ['MMM', 'MMM26', 'MMM30', 'MMM31'],
#     'Name of each exchange on which registered': ['New York Stock Exchange', 'New York Stock Exchange', 'New York Stock Exchange', 'New York Stock Exchange'],
#     'Security Type': ['Common Stock, Par Value $.01 Per Share', '1.500% Notes due 2026', '1.750% Notes due 2030', '1.500% Notes due 2031']
# }
#
# # Create a DataFrame
# df = pd.DataFrame(data)
#
# # Filter the DataFrame to get the debt securities
# debt_securities = df[df['Security Type'].str.contains('Notes', na=False)]
#
# # Print the result
# print(debt_securities)
#   Trading Symbol Name of each exchange on which registered  \
# 1          MMM26                   New York Stock Exchange
# 2          MMM30                   New York Stock Exchange
# 3          MMM31                   New York Stock Exchange
#
#            Security Type
# 1  1.500% Notes due 2026
# 2  1.750% Notes due 2030
# 3  1.500% Notes due 2031
#
# USER>>'Use this fact to answer the question: Title of each class Trading Symbol(s) Name of each exchange on which registered Common Stock, Par Value $.01 Per Share MMM New York Stock Exchange MMM Chicago Stock Exchange, Inc. 1.500% Notes due 2026 MMM26 New York Stock Exchange 1.750% Notes due 2030 MMM30 New York Stock Exchange 1.500% Notes due 2031 MMM31 New York Stock Exchange  Which debt securities are registered to trade on a national securities exchange under 3M's name as of Q2 of 2023?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import pandas as pd
#
# # Define the data
# data = {
#     'Trading Symbol': ['MMM', 'MMM26', 'MMM30', 'MMM31'],
#     'Name of each exchange on which registered': ['New York Stock Exchange', 'New York Stock Exchange', 'New York Stock Exchange', 'New York Stock Exchange'],
#     'Security Type': ['Common Stock, Par Value $.01 Per Share', '1.500% Notes due 2026', '1.750% Notes due 2030', '1.500% Notes due 2031']
# }
#
# # Create a DataFrame
# df = pd.DataFrame(data)
#
# # Filter the DataFrame to get the debt securities
# debt_securities = df[df['Security Type'].str.contains('Notes')]
#
# # Print the result
# print(debt_securities)
#   Trading Symbol Name of each exchange on which registered  \
# 1          MMM26                   New York Stock Exchange
# 2          MMM30                   New York Stock Exchange
# 3          MMM31                   New York Stock Exchange
#
#            Security Type
# 1  1.500% Notes due 2026
# 2  1.750% Notes due 2030
# 3  1.500% Notes due 2031
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import pandas as pd
#
# # Define the data
# data = {
#     'Trading Symbol': ['MMM', 'MMM26', 'MMM30', 'MMM31'],
#     'Name of each exchange on which registered': ['New York Stock Exchange', 'New York Stock Exchange', 'New York Stock Exchange', 'New York Stock Exchange'],
#     'Security Type': ['Common Stock, Par Value $.01 Per Share', '1.500% Notes due 2026', '1.750% Notes due 2030', '1.500% Notes due 2031']
# }
#
# # Create a DataFrame
# df = pd.DataFrame(data)
#
# # Filter the DataFrame to get the debt securities
# debt_securities = df[df['Security Type'].str.contains('Notes', na=False)]
#
# # Print the result
# print(debt_securities)
#   Trading Symbol Name of each exchange on which registered  \
# 1          MMM26                   New York Stock Exchange
# 2          MMM30                   New York Stock Exchange
# 3          MMM31                   New York Stock Exchange
#
#            Security Type
# 1  1.500% Notes due 2026
# 2  1.750% Notes due 2030
# 3  1.500% Notes due 2031
#
# USER>>What are the top perfomers tech stocks in 2024 and graph YTD gains?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Define the list of tech stocks
# tech_stocks = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB', 'TSLA', 'NVDA', 'PYPL', 'ADBE', 'SNPS']
#
# # Get the historical data for each stock
# data = {}
# for stock in tech_stocks:
#     ticker = yf.Ticker(stock)
#     hist = ticker.history(period='max')
#     data[stock] = hist['Close'].iloc[-1]
#
# # Create a DataFrame with the stock prices
# df = pd.DataFrame(list(data.items()), columns=['Stock', 'Price'])
#
# # Sort the DataFrame by price
# df = df.sort_values(by='Price', ascending=False)
#
# # Plot the YTD gains
# plt.figure(figsize=(10,6))
# plt.bar(df['Stock'], df['Price'])
# plt.xlabel('Stock')
# plt.ylabel('Price')
# plt.title('Top Tech Stocks by Price (2024)')
# plt.xticks(rotation=90)
# plt.show()
#
# # Calculate the YTD gains
# ytd_gains = {}
# for stock in tech_stocks:
#     ticker = yf.Ticker(stock)
#     hist = ticker.history(period='max')
#     ytd_gains[stock] = (hist['Close'].iloc[-1] - hist['Close'].iloc[0]) / hist['Close'].iloc[0]
#
# # Create a DataFrame with the YTD gains
# df_ytd = pd.DataFrame(list(ytd_gains.items()), columns=['Stock', 'YTD Gain'])
#
# # Sort the DataFrame by YTD gain
# df_ytd = df_ytd.sort_values(by='YTD Gain', ascending=False)
#
# # Plot the YTD gains
# plt.figure(figsize=(10,6))
# plt.bar(df_ytd['Stock'], df_ytd['YTD Gain'] * 100)
# plt.xlabel('Stock')
# plt.ylabel('YTD Gain (%)')
# plt.title('Top Tech Stocks by YTD Gain (2024)')
# plt.xticks(rotation=90)
# plt.show()
# ERROR:yfinance:$FB: possibly delisted; no timezone found
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# IndexError('single positional indexer is out-of-bounds')
# double checking>>>
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Define the list of tech stocks
# tech_stocks = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB', 'TSLA', 'NVDA', 'PYPL', 'ADBE', 'SNPS']
#
# # Get the historical data for each stock
# data = {}
# for stock in tech_stocks:
#     ticker = yf.Ticker(stock)
#     hist = ticker.history(period='max')
#     data[stock] = hist['Close'].iloc[-1]
#
# # Create a DataFrame with the stock prices
# df = pd.DataFrame(list(data.items()), columns=['Stock', 'Price'])
#
# # Sort the DataFrame by price
# df = df.sort_values(by='Price', ascending=False)
#
# # Plot the stock prices
# plt.figure(figsize=(10,6))
# plt.bar(df['Stock'], df['Price'])
# plt.xlabel('Stock')
# plt.ylabel('Price')
# plt.title('Top Tech Stocks by Price (2024)')
# plt.xticks(rotation=90)
# plt.show()
#
# # Calculate the YTD gains
# ytd_gains = {}
# for stock in tech_stocks:
#     ticker = yf.Ticker(stock)
#     hist = ticker.history(period='max')
#     ytd_gains[stock] = ((hist['Close'].iloc[-1] - hist['Close'].iloc[0]) / hist['Close'].iloc[0]) * 100
#
# # Create a DataFrame with the YTD gains
# df_ytd = pd.DataFrame(list(ytd_gains.items()), columns=['Stock', 'YTD Gain'])
#
# # Sort the DataFrame by YTD gain
# df_ytd = df_ytd.sort_values(by='YTD Gain', ascending=False)
#
# # Plot the YTD gains
# plt.figure(figsize=(10,6))
# plt.bar(df_ytd['Stock'], df_ytd['YTD Gain'])
# plt.xlabel('Stock')
# plt.ylabel('YTD Gain (%)')
# plt.title('Top Tech Stocks by YTD Gain (2024)')
# plt.xticks(rotation=90)
# plt.show()
# ERROR:yfinance:$FB: possibly delisted; no timezone found
# IndexError('single positional indexer is out-of-bounds')
# USER>>What are the top perfomers tech stocks in 2024 and graph YTD gains using Yahoo Finance.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Get the top performers tech stocks in 2024
# tech_stocks = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB', 'TSLA', 'NVDA', 'PYPL', 'ADBE', 'SNPS']
# df = pd.DataFrame(columns=['Stock', 'YTD Gain'])
#
# for stock in tech_stocks:
#     ticker = yf.Ticker(stock)
#     info = ticker.info
#     ytd_change = info['regularMarketPrice'] / info['previousClose'] - 1
#     df = pd.concat([df, pd.DataFrame([[stock, ytd_change*100]], columns=['Stock', 'YTD Gain'])], ignore_index=True)
#
# # Sort the dataframe by YTD gain in descending order
# df = df.sort_values(by='YTD Gain', ascending=False)
#
# # Plot the YTD gains
# plt.figure(figsize=(10,6))
# plt.bar(df['Stock'], df['YTD Gain'])
# plt.xlabel('Stock')
# plt.ylabel('YTD Gain (%)')
# plt.title('Top Performers Tech Stocks in 2024')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
# KeyError('regularMarketPrice')
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Get the top performers tech stocks in 2024
# tech_stocks = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB', 'TSLA', 'NVDA', 'PYPL', 'ADBE', 'SNPS']
# df = pd.DataFrame(columns=['Stock', 'YTD Gain'])
#
# for stock in tech_stocks:
#     ticker = yf.Ticker(stock)
#     info = ticker.info
#     if'regularMarketPrice' in info and 'previousClose' in info:
#         ytd_change = (info['regularMarketPrice'] / info['previousClose'] - 1) * 100
#         df = pd.concat([df, pd.DataFrame([[stock, ytd_change]], columns=['Stock', 'YTD Gain'])], ignore_index=True)
#     else:
#         print(f"Error: Unable to retrieve data for {stock}")
#
# # Sort the dataframe by YTD gain in descending order
# df = df.sort_values(by='YTD Gain', ascending=False)
#
# # Plot the YTD gains
# plt.figure(figsize=(10,6))
# plt.bar(df['Stock'], df['YTD Gain'])
# plt.xlabel('Stock')
# plt.ylabel('YTD Gain (%)')
# plt.title('Top Performers Tech Stocks in 2024')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
# Error: Unable to retrieve data for AAPL
# Error: Unable to retrieve data for GOOG
# Error: Unable to retrieve data for MSFT
# Error: Unable to retrieve data for AMZN
# Error: Unable to retrieve data for FB
# Error: Unable to retrieve data for TSLA
# Error: Unable to retrieve data for NVDA
# Error: Unable to retrieve data for PYPL
# Error: Unable to retrieve data for ADBE
# Error: Unable to retrieve data for SNPS
#
# USER>>What are the top perfomers tech stocks in 2024 and graph YTD gains with Yahoo Finance with brave_search.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
# from datetime import datetime
# from bs4 import BeautifulSoup
# import requests
#
# # Get the current year
# year = datetime.now().year
#
# # Search for the top performers tech stocks in 2024 on Yahoo Finance
# url = f"https://finance.yahoo.com/news/top-performing-tech-stocks-2024/{year}"
# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')
#
# # Extract the stock names and their YTD gains from the webpage
# stocks = []
# for table in soup.find_all('table'):
#     for row in table.find_all('tr'):
#         cols = row.find_all('td')
#         if len(cols) > 0:
#             stock_name = cols[0].text.strip()
#             ytd_gain = cols[1].text.strip()
#             stocks.append((stock_name, ytd_gain))
#
# # Convert the list of stocks to a pandas DataFrame
# df = pd.DataFrame(stocks, columns=['Stock Name', 'YTD Gain'])
#
# # Filter the DataFrame to only include tech stocks
# tech_stocks = df[df['Stock Name'].str.contains('Tech')]
#
# # Plot the YTD gains of the top performers
# plt.figure(figsize=(10,6))
# plt.bar(tech_stocks['Stock Name'], tech_stocks['YTD Gain'])
# plt.xlabel('Stock Name')
# plt.ylabel('YTD Gain')
# plt.title('Top Performing Tech Stocks in 2024')
# plt.xticks(rotation=90)
# plt.tight_layout()
# plt.show()
# IndexError('list index out of range')
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
# from datetime import datetime
# from bs4 import BeautifulSoup
# import requests
#
# # Get the current year
# year = datetime.now().year
#
# # Search for the top performers tech stocks in 2024 on Yahoo Finance
# url = f"https://finance.yahoo.com/news/top-performing-tech-stocks-{year}/"
# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')
#
# # Extract the stock names and their YTD gains from the webpage
# stocks = []
# for table in soup.find_all('table'):
#     for row in table.find_all('tr'):
#         cols = row.find_all('td')
#         if len(cols) > 0:
#             stock_name = cols[0].text.strip()
#             ytd_gain = cols[1].text.strip()
#             stocks.append((stock_name, ytd_gain))
#
# # Convert the list of stocks to a pandas DataFrame
# df = pd.DataFrame(stocks, columns=['Stock Name', 'YTD Gain'])
#
# # Filter the DataFrame to only include tech stocks
# tech_stocks = df[df['Stock Name'].str.contains('Tech', na=False)]
#
# # Plot the YTD gains of the top performers
# plt.figure(figsize=(10,6))
# tech_stocks['YTD Gain'] = pd.to_numeric(tech_stocks['YTD Gain']) # convert YTD Gain to numeric
# plt.bar(tech_stocks['Stock Name'], tech_stocks['YTD Gain'])
# plt.xlabel('Stock Name')
# plt.ylabel('YTD Gain')
# plt.title('Top Performing Tech Stocks in 2024')
# plt.xticks(rotation=90)
# plt.tight_layout()
# plt.show()
# IndexError('list index out of range')
# USER>>What are the top performers tech stocks in 2024 using Yahoo Finance
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import yfinance as yf
# from datetime import datetime, timedelta
# from pandas import DataFrame
#
# # Define the start and end dates for the data
# start_date = datetime.today() - timedelta(days=365)
# ...
#   warnings.warn(
# import numpy as np
#
# # Define the first term (a) and the common difference (d)
# a = 6
# d = 7
#
# # Define the number of terms (n)
# n = 5
#
# # Calculate the arithmetic sequence
# sequence = [a + i * d for i in range(n)]
#
# # Print the sequence
# print(sequence)
# NameError("name 'a' is not defined")
# USER>>Find the arithmetic sequence up to 5 terms if first term(a) = 6, and common difference(d) = 7 and verify it using the online sequence calculator. NameError("name 'a' is not defined")
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import numpy as np
#
# # Define the first term (a) and common difference (d)
# a = 6
# d = 7
#
# # Define the number of terms (n)
# n = 5
#
# # Calculate the arithmetic sequence
# sequence = [a + i * d for i in range(n)]
#
# # Print the sequence
# print(sequence)
# NameError("name 'a' is not defined")
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import numpy as np
#
# # Define the first term (a) and common difference (d)
# a = 6
# d = 7
#
# # Define the number of terms (n)
# n = 5
#
# # Calculate the arithmetic sequence
# sequence = [a + i * d for i in range(n)]
#
# # Print the sequence
# print(sequence)
# NameError("name 'a' is not defined")
# USER>>Ms. Natalie earns $200,000 per annum and her salary increases by $25,000 per annum. Then how much does she earn at the end of the first 5 years?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# USER>>Ms. Natalie earns $200,000 per annum and her salary increases by $25,000 per annum. Then how much does she earn at the end of the first 5 years?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# USER>>Ms. Natalie earns $200,000 per annum and her salary increases by $25,000 per annum. Then how much does she earn at the end of the first 5 years?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# USER>>Use python: Ms. Natalie earns $200,000 per annum and her salary increases by $25,000 per annum. Then how much does she earn at the end of the first 5 years?
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# # Initial salary
# initial_salary = 200000
#
# # Annual increment
# annual_increment = 25000
#
# # Number of years
# years = 5
#
# # Calculate the total increment
# total_increment = annual_increment * years
#
# # Calculate the final salary
# final_salary = initial_salary + total_increment
#
# print(final_salary)
# 325000
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import math
#
# # Initial salary
# initial_salary = 200000
#
# # Annual increment
# annual_increment = 25000
#
# # Number of years
# years = 5
#
# # Calculate the total increment
# total_increment = annual_increment * years
#
# # Calculate the final salary
# final_salary = initial_salary + total_increment
#
# # Print the final salary
# print(final_salary)
# 325000
#
# USER>>Ms. Natalie earns $200,000 per annum and her salary increases by $25,000 per annum. Then how much does she earn at the end of the first 5 years? Using Arithmetic Sequence
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import numpy as np
#
# # Define the initial salary and annual increase
# initial_salary = 200000
# annual_increase = 25000
#
# # Calculate the total salary after 5 years using the formula for the sum of an arithmetic sequence
# total_salary = (initial_salary + (5 * annual_increase)) + (5 * (5 * 2) / 2) * annual_increase
#
# print(total_salary)
# 950000.0
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import numpy as np
#
# # Define the initial salary and annual increase
# initial_salary = 200000
# annual_increase = 25000
#
# # Calculate the total salary after 5 years using the formula for the sum of an arithmetic sequence
# total_salary = (initial_salary + (5 * annual_increase)) + (5 * (5 + 1) / 2) * annual_increase
#
# print(total_salary)
# 700000.0
#
# USER>>(dy/dx) = x2y + y
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import sympy as sp
#
# # Define the variable
# x = sp.symbols('x')
# y = sp.Function('y')
#
# # Define the differential equation
# eq = sp.Eq(y(x).diff(x), x**2*y(x) + y(x))
#
# # Solve the differential equation
# sol = sp.dsolve(eq)
#
# print(sol)
# Eq(y(x), C1*exp(x*(x**2/3 + 1)))
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import sympy as sp
#
# # Define the variable
# x = sp.symbols('x')
# y = sp.Function('y')
#
# # Define the differential equation
# eq = sp.Eq(sp.diff(y(x), x), x**2*y(x) + y(x))
#
# # Solve the differential equation
# sol = sp.dsolve(eq, y(x))
#
# print(sol)
# Eq(y(x), C1*exp(x*(x**2/3 + 1)))
#
# USER>>Find f'(x) for the following function f(x) using the product rule: f(x) = x·log x.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import sympy as sp
#
# x = sp.symbols('x')
#
# f = x * sp.log(x)
#
# f_prime = sp.diff(f, x)
#
# print(f_prime)
# log(x) + 1
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import sympy as sp
#
# x = sp.symbols('x')
#
# f = x * sp.log(x)
#
# f_prime = sp.diff(f, x)
#
# print(f_prime)
# log(x) + 1
#
# USER>>To find the derivative of d/dx (sin 2x), express sin 2x = f(g(x)), where f(x) = sin x and g(x) = 2x.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import sympy as sp
#
# # Define the variable
# x = sp.symbols('x')
#
# # Define the function
# f = sp.sin(2*x)
# g = 2*x
#
# # Find the derivative using the chain rule
# f_prime = sp.diff(f, x)
# g_prime = sp.diff(g, x)
#
# # Apply the chain rule
# derivative = f_prime * g_prime
#
# print(derivative)
# 4*cos(2*x)
#
# double checking>>>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:601: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:606: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# import sympy as sp
#
# # Define the variable
# x = sp.symbols('x')
#
# # Define the function
# f = sp.sin(2*x)
# g = 2*x
#
# # Find the derivative using the chain rule
# f_prime = sp.diff(f, x)
# g_prime = sp.diff(g, x)
#
# # Apply the chain rule
# derivative = f_prime * g
#
# print(derivative)
# 4*x*cos(2*x)
